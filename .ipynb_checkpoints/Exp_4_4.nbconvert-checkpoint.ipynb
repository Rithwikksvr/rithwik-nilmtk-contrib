# %%
from api import API
# Out:
# /home/nilmtk/anaconda3/envs/nv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# Using TensorFlow backend.
# /home/nilmtk/anaconda3/envs/nv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /home/nilmtk/anaconda3/envs/nv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
redd = {
  'power': {
    'mains': ['apparent','active'],
    'appliance': ['apparent','active']
  },
  'sample_rate': 60,
  'appliances': ['washing machine','fridge'],
  'methods': {
    'Mean': {},"CO":{},"FHMM_EXACT":{'num_of_states':2},
        'Seq2Point':{'n_epochs':10},
       "Seq2Seq":{'n_epochs':10},
      'RNN':{'n_epochs':10}
      
#       ,"WindowGRU":{'n_epochs':10},
#               'DAE':{'n_epochs':10}
      
  },
    
  'train': {
    'datasets': {
      'UKDALE': {
        'path': '/home/nilmtk/nilmtk-contrib/ukdale.h5',
        'buildings': {
              1: {
                'start_time': '2017-01-05',
                'end_time': '2017-03-05'#
              },
          
        }
      },
        
    }
  },
    
  'test': {
    'datasets': {
      'DRED': {
        'path': '/home/nilmtk/nilmtk-contrib/DRED.h5',
        'buildings': {
              1: {
                    'start_time': '2015-09-21',
                    'end_time': '2015-10-01'
          }
        }
      },
      'REDD': {
        'path': '/home/nilmtk/redd.h5',
        'buildings': {
              1: {
                    'start_time': '2011-04-17',
                    'end_time': '2011-04-27'
          }
        }
      }
    },
    'metrics': ['mae', 'rmse']
  }
}

# %%
API(redd)
# Out:
# Started training for  WindowGRU
# <disaggregate.WindowGRU.WindowGRU object at 0x7f17812aacf8> False None
# Joint training for  WindowGRU
# ............... Loading Data for training ...................
# Loading data for  UKDALE  dataset
# Loading building ...  1
# Dropping missing values
# Train Jointly
# (84445, 1) (84445, 1) MultiIndex(levels=[['power', 'voltage'], ['', 'active', 'apparent']],
#            codes=[[0], [1]],
#            names=['physical_quantity', 'type']) MultiIndex(levels=[['power'], ['active']],
#            codes=[[0], [0]],
#            names=['physical_quantity', 'type'])
# Training processing
# First model training for  washing machine
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 65s 905us/step - loss: 0.0112 - val_loss: 0.0091
#
# Epoch 00001: val_loss improved from inf to 0.00911, saving model to temp-weights.h5
# First model training for  fridge
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 65s 904us/step - loss: 7.0062e-04 - val_loss: 6.2614e-04
#
# Epoch 00001: val_loss improved from inf to 0.00063, saving model to temp-weights.h5
# <disaggregate.WindowGRU.WindowGRU object at 0x7f17812aacf8> False None
# Joint training for  WindowGRU
# ............... Loading Data for training ...................
# Loading data for  UKDALE  dataset
# Loading building ...  1
# Dropping missing values
# Train Jointly
# (84445, 1) (84445, 1) MultiIndex(levels=[['power', 'voltage'], ['', 'active', 'apparent']],
#            codes=[[0], [1]],
#            names=['physical_quantity', 'type']) MultiIndex(levels=[['power'], ['active']],
#            codes=[[0], [0]],
#            names=['physical_quantity', 'type'])
# Training processing
# Started re-training model for  washing machine
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 824us/step - loss: 0.0100 - val_loss: 0.0113
#
# Epoch 00001: val_loss improved from inf to 0.01134, saving model to temp-weights.h5
# Started re-training model for  fridge
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 819us/step - loss: 6.1378e-04 - val_loss: 5.3092e-04
#
# Epoch 00001: val_loss improved from inf to 0.00053, saving model to temp-weights.h5
# <disaggregate.WindowGRU.WindowGRU object at 0x7f17812aacf8> False None
# Joint training for  WindowGRU
# ............... Loading Data for training ...................
# Loading data for  UKDALE  dataset
# Loading building ...  1
# Dropping missing values
# Train Jointly
# (84445, 1) (84445, 1) MultiIndex(levels=[['power', 'voltage'], ['', 'active', 'apparent']],
#            codes=[[0], [1]],
#            names=['physical_quantity', 'type']) MultiIndex(levels=[['power'], ['active']],
#            codes=[[0], [0]],
#            names=['physical_quantity', 'type'])
# Training processing
# Started re-training model for  washing machine
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 822us/step - loss: 0.0098 - val_loss: 0.0103
#
# Epoch 00001: val_loss improved from inf to 0.01034, saving model to temp-weights.h5
# Started re-training model for  fridge
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 821us/step - loss: 5.4801e-04 - val_loss: 4.6512e-04
#
# Epoch 00001: val_loss improved from inf to 0.00047, saving model to temp-weights.h5
# <disaggregate.WindowGRU.WindowGRU object at 0x7f17812aacf8> False None
# Joint training for  WindowGRU
# ............... Loading Data for training ...................
# Loading data for  UKDALE  dataset
# Loading building ...  1
# Dropping missing values
# Train Jointly
# (84445, 1) (84445, 1) MultiIndex(levels=[['power', 'voltage'], ['', 'active', 'apparent']],
#            codes=[[0], [1]],
#            names=['physical_quantity', 'type']) MultiIndex(levels=[['power'], ['active']],
#            codes=[[0], [0]],
#            names=['physical_quantity', 'type'])
# Training processing
# Started re-training model for  washing machine
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 821us/step - loss: 0.0097 - val_loss: 0.0088
#
# Epoch 00001: val_loss improved from inf to 0.00883, saving model to temp-weights.h5
# Started re-training model for  fridge
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 820us/step - loss: 4.9390e-04 - val_loss: 4.7533e-04
#
# Epoch 00001: val_loss improved from inf to 0.00048, saving model to temp-weights.h5
# <disaggregate.WindowGRU.WindowGRU object at 0x7f17812aacf8> False None
# Joint training for  WindowGRU
# ............... Loading Data for training ...................
# Loading data for  UKDALE  dataset
# Loading building ...  1
# Dropping missing values
# Train Jointly
# (84445, 1) (84445, 1) MultiIndex(levels=[['power', 'voltage'], ['', 'active', 'apparent']],
#            codes=[[0], [1]],
#            names=['physical_quantity', 'type']) MultiIndex(levels=[['power'], ['active']],
#            codes=[[0], [0]],
#            names=['physical_quantity', 'type'])
# Training processing
# Started re-training model for  washing machine
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 821us/step - loss: 0.0096 - val_loss: 0.0080
#
# Epoch 00001: val_loss improved from inf to 0.00795, saving model to temp-weights.h5
# Started re-training model for  fridge
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 820us/step - loss: 4.7074e-04 - val_loss: 4.5247e-04
#
# Epoch 00001: val_loss improved from inf to 0.00045, saving model to temp-weights.h5
# <disaggregate.WindowGRU.WindowGRU object at 0x7f17812aacf8> False None
# Joint training for  WindowGRU
# ............... Loading Data for training ...................
# Loading data for  UKDALE  dataset
# Loading building ...  1
# Dropping missing values
# Train Jointly
# (84445, 1) (84445, 1) MultiIndex(levels=[['power', 'voltage'], ['', 'active', 'apparent']],
#            codes=[[0], [1]],
#            names=['physical_quantity', 'type']) MultiIndex(levels=[['power'], ['active']],
#            codes=[[0], [0]],
#            names=['physical_quantity', 'type'])
# Training processing
# Started re-training model for  washing machine
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 71778/71778 [==============================] - 59s 822us/step - loss: 0.0095 - val_loss: 0.0093
#
# Epoch 00001: val_loss improved from inf to 0.00933, saving model to temp-weights.h5
# Started re-training model for  fridge
# Train on 71778 samples, validate on 12667 samples
# Epoch 1/1
# 61952/71778 [========================>.....] - ETA: 7s - loss: 4.5505e-04
